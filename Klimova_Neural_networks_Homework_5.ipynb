# %% [markdown]
# # Введение в искусственные нейронные сети
# # Урок 5. Рекуррентные нейронные сети

# %% [markdown]
# ## Практическое задание
#
# <ol>
#     Попробуйте обучить нейронную сеть LSTM на любом другом датасете (любимый временной ряд, текст на русском (другом языке) как генератор или классификатор, или прилагаемый набор airline-passengers - пасажиропоток для авиалиний). Опишите, какой результата вы получили? Что помогло вам улучшить ее точность?
#
# </ol>

# %% [markdown]
# Данные возьмем с соревнования: https://www.kaggle.com/competitions/nbme-score-clinical-patient-notes

# %%
import pandas as pd
import numpy as np
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings("ignore")

# %%
import tensorflow as tf
from keras.preprocessing import sequence, text
from keras.models import Sequential
from keras.layers import Dense, Embedding, Dropout, LSTM
from keras.callbacks import EarlyStopping
from keras import regularizers

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.head()
# Out:
#           id  case_num  pn_num  feature_num  \
# 0  00016_000         0      16            0
# 1  00016_001         0      16            1
# 2  00016_002         0      16            2
# 3  00016_003         0      16            3
# 4  00016_004         0      16            4
#
#                                  annotation              location
# 0          ['dad with recent heart attcak']           ['696 724']
# 1             ['mom with "thyroid disease']           ['668 693']
# 2                        ['chest pressure']           ['203 217']
# 3      ['intermittent episodes', 'episode']  ['70 91', '176 183']
# 4  ['felt as if he were going to pass out']           ['222 258']

# %%
list_annotation = []
for index, row in df_train.iterrows():
    list_annotation.append(row['annotation'][2:-2])

# %%
df_train['annotation'] = list_annotation

# %%
df_train.case_num.value_counts()
# Out:
# 5    1800
# 8    1800
# 2    1700
# 9    1700
# 3    1600
# 0    1300
# 1    1300
# 6    1200
# 4    1000
# 7     900
# Name: case_num, dtype: int64

# %%
MAX_NB_WORDS = 100000
MAX_SEQUENCE_LENGTH = 250
tokenizer = text.Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(df_train['annotation'].values)
word_index = tokenizer.word_index

# %%
X = tokenizer.texts_to_sequences(df_train['annotation'].values)
X = sequence.pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
X.shape
# Out:
# (14300, 250)

# %%
y = pd.get_dummies(df_train['case_num']).values
y.shape
# Out:
# (14300, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, random_state = 42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (12870, 250) (12870, 10)
# (1430, 250) (1430, 10)

# %%
callback = EarlyStopping( monitor='val_accuracy', patience=10)

# %%
total_words = len(tokenizer.word_index) + 1

# %%
column_name_result = ['index', 'iteration', 'loss_name', 'optimizer_name', 
                      'valid_accuracy', 'test_accuracy']
df_result = pd.DataFrame(columns=column_name_result)

# %%
def creation_model():
    model = Sequential()
    model.add(Embedding(total_words, 1024, input_length=X.shape[1]))  
    model.add(LSTM(128))
    model.add(Dropout(0.2))
    model.add(Dense(total_words / 2, activation='relu', 
                    kernel_regularizer=regularizers.l2(0.1)))
    model.add(Dropout(0.2))
    model.add(Dense(total_words / 4, activation='relu', 
                    kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dropout(0.2))
    model.add(Dense(total_words / 10, activation='relu', 
                    kernel_regularizer=regularizers.l2(0.1)))
    model.add(Dropout(0.2))
    model.add(Dense(total_words / 25, activation='relu',
                    kernel_regularizer=regularizers.l2(0.01)))
    model.add(Dense(10, activation='softmax'))
    return model

# %%
def modeling(loss_func, optimizer_func, epoch, batch, train_features,
             train_labels, df_result, count, test_features, test_labels):
  for iter in [1, 2, 3]:
    model = creation_model()
    model.compile(optimizer=optimizer_func,
                  loss=loss_func,
                  metrics=['accuracy'])
  
    with tf.device("GPU:0"):
      history = model.fit(train_features, 
                    train_labels, 
                    epochs=epoch, 
                    batch_size=batch,
                    validation_split=0.2, 
                    verbose=2)
    
    predictions = model.predict(X_test)
    preds = np.argmax(predictions, axis=1)
    test_real = np.argmax(y_test, axis=1)
    test_accuracy = accuracy_score(test_real, preds)

    dict_result = dict()
    dict_result['index'] = count
    dict_result['iteration'] = int(iter)
    dict_result['loss_name'] = loss_func
    dict_result['optimizer_name'] = optimizer_func
    dict_result['valid_accuracy'] = history.history['val_accuracy'][-1]
    dict_result['test_accuracy'] = test_accuracy
    print(dict_result)
    df_result = pd.concat([df_result, pd.DataFrame(dict_result, index=range(count, count+1))])
    count += 1
  return df_result, count

# %%
# %%time
epoch = 30
batch = 128
count = 0

optimizer = ['adam', 'nadam', 'sgd', 'rmsprop']  
loss = ['categorical_crossentropy', 'kullback_leibler_divergence']

for loss, optimize in itertools.product(loss, optimizer):
    df_result, count = modeling(loss, optimize, epoch, batch, 
                              X_train, y_train, df_result, count, 
                              X_test, y_test)
# Out:
# Epoch 1/30
# 81/81 - 13s - loss: 21.0248 - accuracy: 0.1197 - val_loss: 2.8537 - val_accuracy: 0.1309 - 13s/epoch - 156ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.3941 - accuracy: 0.1246 - val_loss: 2.2824 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.2802 - accuracy: 0.1223 - val_loss: 2.2760 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.2783 - accuracy: 0.1219 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.2783 - accuracy: 0.1222 - val_loss: 2.2753 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.2781 - accuracy: 0.1223 - val_loss: 2.2752 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.2780 - accuracy: 0.1246 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1214 - val_loss: 2.2752 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1234 - val_loss: 2.2753 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1238 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1188 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1219 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 109ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1246 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 109ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1238 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 109ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1246 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 109ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1209 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 109ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1229 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 109ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1201 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 109ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1230 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1209 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1208 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1226 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1206 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1237 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1247 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1235 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1220 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1224 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1250 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1210 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# {'index': 0, 'iteration': 1, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'adam', 'valid_accuracy': 0.13092462718486786, 'test_accuracy': 0.1258741258741259}
# Epoch 1/30
# 81/81 - 12s - loss: 21.0299 - accuracy: 0.1224 - val_loss: 2.8540 - val_accuracy: 0.1282 - 12s/epoch - 146ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.3945 - accuracy: 0.1226 - val_loss: 2.2827 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.2807 - accuracy: 0.1242 - val_loss: 2.2757 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.2784 - accuracy: 0.1236 - val_loss: 2.2759 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.2783 - accuracy: 0.1258 - val_loss: 2.2752 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1257 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.2782 - accuracy: 0.1238 - val_loss: 2.2754 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1247 - val_loss: 2.2754 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.2781 - accuracy: 0.1227 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 2.2781 - accuracy: 0.1223 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 2.2782 - accuracy: 0.1199 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1169 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1233 - val_loss: 2.2752 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1213 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1225 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1233 - val_loss: 2.2753 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1211 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1187 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1246 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 2.2776 - accuracy: 0.1243 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1210 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1221 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1231 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1231 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1178 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1186 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1246 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1210 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1212 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1248 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# {'index': 1, 'iteration': 2, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'adam', 'valid_accuracy': 0.13092462718486786, 'test_accuracy': 0.1258741258741259}
# Epoch 1/30
# 81/81 - 12s - loss: 21.0142 - accuracy: 0.1201 - val_loss: 2.8464 - val_accuracy: 0.1282 - 12s/epoch - 146ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.3914 - accuracy: 0.1182 - val_loss: 2.2821 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.2799 - accuracy: 0.1205 - val_loss: 2.2753 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.2782 - accuracy: 0.1223 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.2780 - accuracy: 0.1180 - val_loss: 2.2752 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.2782 - accuracy: 0.1268 - val_loss: 2.2752 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.2781 - accuracy: 0.1246 - val_loss: 2.2752 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.2780 - accuracy: 0.1239 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1233 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 2.2780 - accuracy: 0.1219 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1215 - val_loss: 2.2749 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1205 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1233 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1212 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1233 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1241 - val_loss: 2.2754 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1236 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1227 - val_loss: 2.2751 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1240 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1208 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1225 - val_loss: 2.2753 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1216 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1233 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 114ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1246 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1233 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1233 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1246 - val_loss: 2.2752 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1236 - val_loss: 2.2750 - val_accuracy: 0.1282 - 9s/epoch - 108ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 2.2777 - accuracy: 0.1224 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1246 - val_loss: 2.2752 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# {'index': 2, 'iteration': 3, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'adam', 'valid_accuracy': 0.12820513546466827, 'test_accuracy': 0.13076923076923078}
# Epoch 1/30
# 81/81 - 14s - loss: 24.5127 - accuracy: 0.1210 - val_loss: 3.5744 - val_accuracy: 0.1309 - 14s/epoch - 168ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.5544 - accuracy: 0.1250 - val_loss: 2.2439 - val_accuracy: 0.1612 - 9s/epoch - 110ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1760 - accuracy: 0.1723 - val_loss: 2.1625 - val_accuracy: 0.1760 - 9s/epoch - 110ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1091 - accuracy: 0.1833 - val_loss: 2.1155 - val_accuracy: 0.1838 - 9s/epoch - 110ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.0735 - accuracy: 0.1937 - val_loss: 2.1079 - val_accuracy: 0.1857 - 9s/epoch - 110ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0462 - accuracy: 0.2022 - val_loss: 2.0741 - val_accuracy: 0.2055 - 9s/epoch - 110ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0142 - accuracy: 0.2211 - val_loss: 2.0807 - val_accuracy: 0.2168 - 9s/epoch - 110ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 1.9931 - accuracy: 0.2324 - val_loss: 2.0458 - val_accuracy: 0.2347 - 9s/epoch - 110ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 1.9805 - accuracy: 0.2418 - val_loss: 2.0995 - val_accuracy: 0.2211 - 9s/epoch - 110ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9675 - accuracy: 0.2450 - val_loss: 2.0664 - val_accuracy: 0.2354 - 9s/epoch - 110ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9554 - accuracy: 0.2459 - val_loss: 2.1276 - val_accuracy: 0.2172 - 9s/epoch - 110ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9575 - accuracy: 0.2451 - val_loss: 2.0340 - val_accuracy: 0.2463 - 9s/epoch - 110ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9410 - accuracy: 0.2469 - val_loss: 2.1806 - val_accuracy: 0.1663 - 9s/epoch - 110ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9334 - accuracy: 0.2566 - val_loss: 2.0448 - val_accuracy: 0.2483 - 9s/epoch - 111ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9209 - accuracy: 0.2716 - val_loss: 2.0097 - val_accuracy: 0.2618 - 9s/epoch - 110ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9179 - accuracy: 0.2775 - val_loss: 2.0073 - val_accuracy: 0.2976 - 9s/epoch - 110ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.8995 - accuracy: 0.2879 - val_loss: 2.0218 - val_accuracy: 0.2754 - 9s/epoch - 109ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.8940 - accuracy: 0.2957 - val_loss: 2.0134 - val_accuracy: 0.2821 - 9s/epoch - 110ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8810 - accuracy: 0.3017 - val_loss: 2.0060 - val_accuracy: 0.3217 - 9s/epoch - 109ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8654 - accuracy: 0.3069 - val_loss: 2.0644 - val_accuracy: 0.2821 - 9s/epoch - 110ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8655 - accuracy: 0.3138 - val_loss: 1.9944 - val_accuracy: 0.3038 - 9s/epoch - 109ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8522 - accuracy: 0.3219 - val_loss: 1.9706 - val_accuracy: 0.3190 - 9s/epoch - 110ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8480 - accuracy: 0.3258 - val_loss: 2.0059 - val_accuracy: 0.2875 - 9s/epoch - 109ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8400 - accuracy: 0.3228 - val_loss: 2.0016 - val_accuracy: 0.2968 - 9s/epoch - 111ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8336 - accuracy: 0.3215 - val_loss: 2.0393 - val_accuracy: 0.2789 - 9s/epoch - 110ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8201 - accuracy: 0.3347 - val_loss: 1.9732 - val_accuracy: 0.3104 - 9s/epoch - 110ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8151 - accuracy: 0.3275 - val_loss: 1.9406 - val_accuracy: 0.3112 - 9s/epoch - 109ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8086 - accuracy: 0.3269 - val_loss: 1.9360 - val_accuracy: 0.3236 - 9s/epoch - 110ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.7948 - accuracy: 0.3320 - val_loss: 1.9313 - val_accuracy: 0.3263 - 9s/epoch - 116ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.7893 - accuracy: 0.3345 - val_loss: 1.9414 - val_accuracy: 0.3092 - 9s/epoch - 110ms/step
# {'index': 3, 'iteration': 1, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'nadam', 'valid_accuracy': 0.309246301651001, 'test_accuracy': 0.3006993006993007}
# Epoch 1/30
# 81/81 - 13s - loss: 24.5264 - accuracy: 0.1227 - val_loss: 3.5649 - val_accuracy: 0.1309 - 13s/epoch - 161ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.5455 - accuracy: 0.1295 - val_loss: 2.2148 - val_accuracy: 0.1535 - 9s/epoch - 110ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1926 - accuracy: 0.1693 - val_loss: 2.1652 - val_accuracy: 0.1725 - 9s/epoch - 110ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1416 - accuracy: 0.1732 - val_loss: 2.1419 - val_accuracy: 0.1818 - 9s/epoch - 110ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.1010 - accuracy: 0.1905 - val_loss: 2.1218 - val_accuracy: 0.1946 - 9s/epoch - 110ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0591 - accuracy: 0.1974 - val_loss: 2.0827 - val_accuracy: 0.2078 - 9s/epoch - 110ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0267 - accuracy: 0.2104 - val_loss: 2.0829 - val_accuracy: 0.2187 - 9s/epoch - 109ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.0058 - accuracy: 0.2209 - val_loss: 2.0445 - val_accuracy: 0.2366 - 9s/epoch - 110ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 1.9798 - accuracy: 0.2360 - val_loss: 2.0523 - val_accuracy: 0.2382 - 9s/epoch - 110ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9782 - accuracy: 0.2369 - val_loss: 2.0620 - val_accuracy: 0.2358 - 9s/epoch - 110ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9604 - accuracy: 0.2406 - val_loss: 2.0703 - val_accuracy: 0.2113 - 9s/epoch - 110ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9465 - accuracy: 0.2443 - val_loss: 2.0449 - val_accuracy: 0.2339 - 9s/epoch - 110ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9382 - accuracy: 0.2440 - val_loss: 2.0083 - val_accuracy: 0.2552 - 9s/epoch - 109ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9302 - accuracy: 0.2480 - val_loss: 2.0081 - val_accuracy: 0.2568 - 9s/epoch - 110ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9184 - accuracy: 0.2508 - val_loss: 2.0051 - val_accuracy: 0.2432 - 9s/epoch - 109ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9113 - accuracy: 0.2561 - val_loss: 2.0817 - val_accuracy: 0.2444 - 9s/epoch - 110ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.9066 - accuracy: 0.2627 - val_loss: 2.0397 - val_accuracy: 0.2471 - 9s/epoch - 110ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.8947 - accuracy: 0.2683 - val_loss: 1.9972 - val_accuracy: 0.2735 - 9s/epoch - 116ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8786 - accuracy: 0.2704 - val_loss: 2.0083 - val_accuracy: 0.2681 - 9s/epoch - 110ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8764 - accuracy: 0.2736 - val_loss: 1.9924 - val_accuracy: 0.2657 - 9s/epoch - 110ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8713 - accuracy: 0.2824 - val_loss: 2.0073 - val_accuracy: 0.2657 - 9s/epoch - 110ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8584 - accuracy: 0.2890 - val_loss: 2.0048 - val_accuracy: 0.2568 - 9s/epoch - 110ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8555 - accuracy: 0.2952 - val_loss: 1.9614 - val_accuracy: 0.2828 - 9s/epoch - 110ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8402 - accuracy: 0.3017 - val_loss: 1.9680 - val_accuracy: 0.3135 - 9s/epoch - 109ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8398 - accuracy: 0.3118 - val_loss: 2.0163 - val_accuracy: 0.2887 - 9s/epoch - 116ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8335 - accuracy: 0.3188 - val_loss: 1.9611 - val_accuracy: 0.2925 - 9s/epoch - 109ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8187 - accuracy: 0.3205 - val_loss: 1.9485 - val_accuracy: 0.3081 - 9s/epoch - 109ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8201 - accuracy: 0.3314 - val_loss: 1.9581 - val_accuracy: 0.3271 - 9s/epoch - 110ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8131 - accuracy: 0.3303 - val_loss: 1.9305 - val_accuracy: 0.3209 - 9s/epoch - 110ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.7963 - accuracy: 0.3372 - val_loss: 1.9310 - val_accuracy: 0.3217 - 9s/epoch - 109ms/step
# {'index': 4, 'iteration': 2, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'nadam', 'valid_accuracy': 0.3216783106327057, 'test_accuracy': 0.3090909090909091}
# Epoch 1/30
# 81/81 - 13s - loss: 24.5123 - accuracy: 0.1191 - val_loss: 3.5992 - val_accuracy: 0.1185 - 13s/epoch - 160ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.5072 - accuracy: 0.1579 - val_loss: 2.1723 - val_accuracy: 0.1841 - 9s/epoch - 109ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1152 - accuracy: 0.1947 - val_loss: 2.0765 - val_accuracy: 0.2199 - 9s/epoch - 110ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1740 - accuracy: 0.1850 - val_loss: 2.1037 - val_accuracy: 0.1943 - 9s/epoch - 110ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.0461 - accuracy: 0.2148 - val_loss: 2.1234 - val_accuracy: 0.2137 - 9s/epoch - 110ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0113 - accuracy: 0.2300 - val_loss: 2.0302 - val_accuracy: 0.2323 - 9s/epoch - 116ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 1.9917 - accuracy: 0.2418 - val_loss: 2.0595 - val_accuracy: 0.2145 - 9s/epoch - 109ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 1.9696 - accuracy: 0.2497 - val_loss: 2.0459 - val_accuracy: 0.2249 - 9s/epoch - 116ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 1.9507 - accuracy: 0.2563 - val_loss: 1.9946 - val_accuracy: 0.2521 - 9s/epoch - 110ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9375 - accuracy: 0.2644 - val_loss: 1.9929 - val_accuracy: 0.2661 - 9s/epoch - 109ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9129 - accuracy: 0.2672 - val_loss: 1.9691 - val_accuracy: 0.2673 - 9s/epoch - 109ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.8929 - accuracy: 0.2710 - val_loss: 1.9645 - val_accuracy: 0.2618 - 9s/epoch - 110ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.8847 - accuracy: 0.2631 - val_loss: 1.9420 - val_accuracy: 0.2723 - 9s/epoch - 116ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.8777 - accuracy: 0.2687 - val_loss: 1.9364 - val_accuracy: 0.2646 - 9s/epoch - 110ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.8596 - accuracy: 0.2679 - val_loss: 2.0530 - val_accuracy: 0.2747 - 9s/epoch - 109ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.8464 - accuracy: 0.2695 - val_loss: 1.9366 - val_accuracy: 0.2378 - 9s/epoch - 109ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.8391 - accuracy: 0.2681 - val_loss: 1.9066 - val_accuracy: 0.2541 - 9s/epoch - 109ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.8289 - accuracy: 0.2730 - val_loss: 1.8974 - val_accuracy: 0.2514 - 9s/epoch - 110ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8233 - accuracy: 0.2688 - val_loss: 1.9127 - val_accuracy: 0.2786 - 9s/epoch - 110ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8129 - accuracy: 0.2696 - val_loss: 1.9046 - val_accuracy: 0.2677 - 9s/epoch - 109ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8070 - accuracy: 0.2738 - val_loss: 1.8919 - val_accuracy: 0.2677 - 9s/epoch - 109ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.7988 - accuracy: 0.2745 - val_loss: 1.8734 - val_accuracy: 0.2490 - 9s/epoch - 109ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.7920 - accuracy: 0.2756 - val_loss: 1.8882 - val_accuracy: 0.2685 - 9s/epoch - 109ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.7912 - accuracy: 0.2739 - val_loss: 1.8861 - val_accuracy: 0.2739 - 9s/epoch - 109ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.7876 - accuracy: 0.2815 - val_loss: 1.8740 - val_accuracy: 0.2692 - 9s/epoch - 109ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.7807 - accuracy: 0.2828 - val_loss: 1.8681 - val_accuracy: 0.2852 - 9s/epoch - 109ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.7772 - accuracy: 0.2855 - val_loss: 1.9163 - val_accuracy: 0.2650 - 9s/epoch - 109ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.7749 - accuracy: 0.2861 - val_loss: 1.8798 - val_accuracy: 0.2677 - 9s/epoch - 110ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.7704 - accuracy: 0.2927 - val_loss: 1.9154 - val_accuracy: 0.2622 - 9s/epoch - 109ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.7668 - accuracy: 0.2970 - val_loss: 1.8955 - val_accuracy: 0.2782 - 9s/epoch - 109ms/step
# {'index': 5, 'iteration': 3, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'nadam', 'valid_accuracy': 0.278166264295578, 'test_accuracy': 0.2846153846153846}
# Epoch 1/30
# 81/81 - 12s - loss: 70.7176 - accuracy: 0.1203 - val_loss: 61.6550 - val_accuracy: 0.1523 - 12s/epoch - 143ms/step
# Epoch 2/30
# 81/81 - 8s - loss: 54.5967 - accuracy: 0.1285 - val_loss: 47.9975 - val_accuracy: 0.1309 - 8s/epoch - 105ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 42.8507 - accuracy: 0.1281 - val_loss: 38.0339 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 34.2707 - accuracy: 0.1248 - val_loss: 30.7441 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 27.9827 - accuracy: 0.1248 - val_loss: 25.3901 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 23.3543 - accuracy: 0.1248 - val_loss: 21.4384 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 19.9285 - accuracy: 0.1246 - val_loss: 18.5031 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 17.3746 - accuracy: 0.1246 - val_loss: 16.3051 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 15.4536 - accuracy: 0.1246 - val_loss: 14.6427 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 13.9926 - accuracy: 0.1246 - val_loss: 13.3698 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 12.8666 - accuracy: 0.1246 - val_loss: 12.3808 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 11.9847 - accuracy: 0.1246 - val_loss: 11.5993 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 11.2819 - accuracy: 0.1246 - val_loss: 10.9699 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 10.7103 - accuracy: 0.1246 - val_loss: 10.4526 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 10.2357 - accuracy: 0.1254 - val_loss: 10.0182 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 9.8334 - accuracy: 0.1229 - val_loss: 9.6458 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 9.4849 - accuracy: 0.1243 - val_loss: 9.3200 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 9.1773 - accuracy: 0.1246 - val_loss: 9.0298 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 8.9011 - accuracy: 0.1290 - val_loss: 8.7670 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 8.6493 - accuracy: 0.1223 - val_loss: 8.5256 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 8.4168 - accuracy: 0.1232 - val_loss: 8.3015 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 8.1998 - accuracy: 0.1243 - val_loss: 8.0915 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 7.9957 - accuracy: 0.1202 - val_loss: 7.8930 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 7.8022 - accuracy: 0.1231 - val_loss: 7.7045 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 7.6180 - accuracy: 0.1195 - val_loss: 7.5246 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 7.4419 - accuracy: 0.1278 - val_loss: 7.3523 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 7.2731 - accuracy: 0.1218 - val_loss: 7.1869 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 7.1107 - accuracy: 0.1224 - val_loss: 7.0277 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 6.9544 - accuracy: 0.1272 - val_loss: 6.8743 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 6.8037 - accuracy: 0.1220 - val_loss: 6.7263 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# {'index': 6, 'iteration': 1, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'sgd', 'valid_accuracy': 0.13092462718486786, 'test_accuracy': 0.1258741258741259}
# Epoch 1/30
# 81/81 - 11s - loss: 70.8010 - accuracy: 0.1196 - val_loss: 61.7246 - val_accuracy: 0.1309 - 11s/epoch - 142ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 54.6550 - accuracy: 0.1254 - val_loss: 48.0456 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 42.8909 - accuracy: 0.1243 - val_loss: 38.0666 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 34.2977 - accuracy: 0.1234 - val_loss: 30.7656 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 28.0000 - accuracy: 0.1242 - val_loss: 25.4035 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 23.3646 - accuracy: 0.1242 - val_loss: 21.4459 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 19.9339 - accuracy: 0.1234 - val_loss: 18.5064 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 17.3765 - accuracy: 0.1238 - val_loss: 16.3055 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 15.4531 - accuracy: 0.1242 - val_loss: 14.6410 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 13.9903 - accuracy: 0.1235 - val_loss: 13.3667 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 12.8632 - accuracy: 0.1261 - val_loss: 12.3768 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 11.9806 - accuracy: 0.1230 - val_loss: 11.5946 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 11.2770 - accuracy: 0.1227 - val_loss: 10.9648 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 10.7052 - accuracy: 0.1237 - val_loss: 10.4472 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 10.2305 - accuracy: 0.1207 - val_loss: 10.0128 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 9.8279 - accuracy: 0.1214 - val_loss: 9.6403 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 9.4796 - accuracy: 0.1243 - val_loss: 9.3146 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 9.1721 - accuracy: 0.1238 - val_loss: 9.0244 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 8.8960 - accuracy: 0.1244 - val_loss: 8.7617 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 8.6442 - accuracy: 0.1243 - val_loss: 8.5205 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 8.4117 - accuracy: 0.1236 - val_loss: 8.2965 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 8.1948 - accuracy: 0.1228 - val_loss: 8.0866 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 7.9909 - accuracy: 0.1207 - val_loss: 7.8883 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 7.7975 - accuracy: 0.1217 - val_loss: 7.6999 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 7.6135 - accuracy: 0.1218 - val_loss: 7.5201 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 7.4376 - accuracy: 0.1224 - val_loss: 7.3480 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 7.2688 - accuracy: 0.1202 - val_loss: 7.1827 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 7.1066 - accuracy: 0.1268 - val_loss: 7.0236 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 6.9505 - accuracy: 0.1233 - val_loss: 6.8704 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 6.7999 - accuracy: 0.1210 - val_loss: 6.7225 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# {'index': 7, 'iteration': 2, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'sgd', 'valid_accuracy': 0.13092462718486786, 'test_accuracy': 0.1258741258741259}
# Epoch 1/30
# 81/81 - 12s - loss: 70.7892 - accuracy: 0.1230 - val_loss: 61.7135 - val_accuracy: 0.1309 - 12s/epoch - 145ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 54.6450 - accuracy: 0.1250 - val_loss: 48.0364 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 42.8828 - accuracy: 0.1245 - val_loss: 38.0593 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 34.2914 - accuracy: 0.1246 - val_loss: 30.7598 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 27.9951 - accuracy: 0.1246 - val_loss: 25.3990 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 23.3610 - accuracy: 0.1246 - val_loss: 21.4425 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 19.9310 - accuracy: 0.1247 - val_loss: 18.5037 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 17.3742 - accuracy: 0.1250 - val_loss: 16.3034 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 15.4513 - accuracy: 0.1250 - val_loss: 14.6393 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 13.9890 - accuracy: 0.1239 - val_loss: 13.3653 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 12.8619 - accuracy: 0.1245 - val_loss: 12.3756 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 11.9796 - accuracy: 0.1255 - val_loss: 11.5937 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 11.2763 - accuracy: 0.1259 - val_loss: 10.9640 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 10.7045 - accuracy: 0.1245 - val_loss: 10.4466 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 10.2299 - accuracy: 0.1238 - val_loss: 10.0122 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 9.8274 - accuracy: 0.1245 - val_loss: 9.6398 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 9.4791 - accuracy: 0.1239 - val_loss: 9.3141 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 9.1716 - accuracy: 0.1239 - val_loss: 9.0240 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 8.8955 - accuracy: 0.1236 - val_loss: 8.7613 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 8.6439 - accuracy: 0.1245 - val_loss: 8.5201 - val_accuracy: 0.1309 - 9s/epoch - 112ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 8.4114 - accuracy: 0.1227 - val_loss: 8.2962 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 8.1946 - accuracy: 0.1243 - val_loss: 8.0862 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 7.9906 - accuracy: 0.1263 - val_loss: 7.8880 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 7.7973 - accuracy: 0.1233 - val_loss: 7.6996 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 7.6133 - accuracy: 0.1215 - val_loss: 7.5199 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 7.4373 - accuracy: 0.1215 - val_loss: 7.3477 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 7.2686 - accuracy: 0.1224 - val_loss: 7.1824 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 7.1063 - accuracy: 0.1199 - val_loss: 7.0234 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 6.9503 - accuracy: 0.1216 - val_loss: 6.8702 - val_accuracy: 0.1309 - 9s/epoch - 105ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 6.7996 - accuracy: 0.1249 - val_loss: 6.7223 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# {'index': 8, 'iteration': 3, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'sgd', 'valid_accuracy': 0.13092462718486786, 'test_accuracy': 0.1258741258741259}
# Epoch 1/30
# 81/81 - 12s - loss: 15.7636 - accuracy: 0.1241 - val_loss: 2.3560 - val_accuracy: 0.1414 - 12s/epoch - 152ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.2460 - accuracy: 0.1689 - val_loss: 2.2124 - val_accuracy: 0.1803 - 9s/epoch - 107ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1507 - accuracy: 0.1826 - val_loss: 2.1304 - val_accuracy: 0.1764 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1147 - accuracy: 0.1863 - val_loss: 2.1319 - val_accuracy: 0.1651 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.0831 - accuracy: 0.1958 - val_loss: 2.1082 - val_accuracy: 0.2040 - 9s/epoch - 108ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0580 - accuracy: 0.2097 - val_loss: 2.1165 - val_accuracy: 0.1997 - 9s/epoch - 108ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0276 - accuracy: 0.2259 - val_loss: 2.0561 - val_accuracy: 0.2327 - 9s/epoch - 108ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 1.9983 - accuracy: 0.2349 - val_loss: 2.0794 - val_accuracy: 0.2339 - 9s/epoch - 109ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 1.9880 - accuracy: 0.2444 - val_loss: 2.0215 - val_accuracy: 0.2420 - 9s/epoch - 108ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9683 - accuracy: 0.2551 - val_loss: 2.0197 - val_accuracy: 0.2436 - 9s/epoch - 108ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9450 - accuracy: 0.2609 - val_loss: 2.0369 - val_accuracy: 0.2805 - 9s/epoch - 107ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9355 - accuracy: 0.2622 - val_loss: 1.9729 - val_accuracy: 0.2766 - 9s/epoch - 108ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9167 - accuracy: 0.2782 - val_loss: 1.9667 - val_accuracy: 0.2817 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9025 - accuracy: 0.2845 - val_loss: 1.9804 - val_accuracy: 0.2727 - 9s/epoch - 107ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.8934 - accuracy: 0.2897 - val_loss: 1.9955 - val_accuracy: 0.2758 - 9s/epoch - 107ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.8832 - accuracy: 0.2964 - val_loss: 2.0536 - val_accuracy: 0.2883 - 9s/epoch - 108ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.8727 - accuracy: 0.2920 - val_loss: 1.9645 - val_accuracy: 0.2836 - 9s/epoch - 108ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.8676 - accuracy: 0.2966 - val_loss: 1.9691 - val_accuracy: 0.2677 - 9s/epoch - 108ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8546 - accuracy: 0.2989 - val_loss: 1.9370 - val_accuracy: 0.2871 - 9s/epoch - 108ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8512 - accuracy: 0.3030 - val_loss: 1.9346 - val_accuracy: 0.2956 - 9s/epoch - 108ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8385 - accuracy: 0.3052 - val_loss: 1.9234 - val_accuracy: 0.2786 - 9s/epoch - 108ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8312 - accuracy: 0.3115 - val_loss: 2.0097 - val_accuracy: 0.2972 - 9s/epoch - 108ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8286 - accuracy: 0.3194 - val_loss: 1.9320 - val_accuracy: 0.3073 - 9s/epoch - 109ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8210 - accuracy: 0.3160 - val_loss: 1.9149 - val_accuracy: 0.3046 - 9s/epoch - 109ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8204 - accuracy: 0.3190 - val_loss: 1.9182 - val_accuracy: 0.3186 - 9s/epoch - 109ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8081 - accuracy: 0.3245 - val_loss: 1.9415 - val_accuracy: 0.3046 - 9s/epoch - 109ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8072 - accuracy: 0.3240 - val_loss: 2.0516 - val_accuracy: 0.2743 - 9s/epoch - 109ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.7979 - accuracy: 0.3276 - val_loss: 1.9101 - val_accuracy: 0.3151 - 9s/epoch - 109ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8015 - accuracy: 0.3316 - val_loss: 1.9141 - val_accuracy: 0.3174 - 9s/epoch - 108ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.7978 - accuracy: 0.3231 - val_loss: 1.9383 - val_accuracy: 0.3271 - 9s/epoch - 108ms/step
# {'index': 9, 'iteration': 1, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'rmsprop', 'valid_accuracy': 0.32711732387542725, 'test_accuracy': 0.3118881118881119}
# Epoch 1/30
# 81/81 - 13s - loss: 15.7592 - accuracy: 0.1202 - val_loss: 2.3842 - val_accuracy: 0.1282 - 13s/epoch - 156ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.2576 - accuracy: 0.1605 - val_loss: 2.1976 - val_accuracy: 0.1799 - 9s/epoch - 108ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1674 - accuracy: 0.1840 - val_loss: 2.1544 - val_accuracy: 0.1857 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1224 - accuracy: 0.1891 - val_loss: 2.1743 - val_accuracy: 0.1566 - 9s/epoch - 108ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.0940 - accuracy: 0.1930 - val_loss: 2.1180 - val_accuracy: 0.2036 - 9s/epoch - 108ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0668 - accuracy: 0.2102 - val_loss: 2.0811 - val_accuracy: 0.2242 - 9s/epoch - 108ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0465 - accuracy: 0.2218 - val_loss: 2.0773 - val_accuracy: 0.2261 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.0311 - accuracy: 0.2240 - val_loss: 2.0634 - val_accuracy: 0.2358 - 9s/epoch - 108ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.0108 - accuracy: 0.2363 - val_loss: 2.1845 - val_accuracy: 0.1962 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9981 - accuracy: 0.2400 - val_loss: 2.0351 - val_accuracy: 0.2747 - 9s/epoch - 107ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9807 - accuracy: 0.2550 - val_loss: 2.0333 - val_accuracy: 0.2584 - 9s/epoch - 107ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9673 - accuracy: 0.2569 - val_loss: 2.0509 - val_accuracy: 0.2234 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9552 - accuracy: 0.2710 - val_loss: 2.0369 - val_accuracy: 0.2677 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9474 - accuracy: 0.2742 - val_loss: 2.0720 - val_accuracy: 0.2533 - 9s/epoch - 107ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9352 - accuracy: 0.2819 - val_loss: 2.0077 - val_accuracy: 0.3057 - 9s/epoch - 107ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9230 - accuracy: 0.2882 - val_loss: 2.0405 - val_accuracy: 0.2323 - 9s/epoch - 107ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.9200 - accuracy: 0.2871 - val_loss: 1.9887 - val_accuracy: 0.2782 - 9s/epoch - 107ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.9109 - accuracy: 0.2965 - val_loss: 1.9865 - val_accuracy: 0.3096 - 9s/epoch - 108ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8959 - accuracy: 0.3010 - val_loss: 2.0826 - val_accuracy: 0.2405 - 9s/epoch - 107ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8964 - accuracy: 0.3025 - val_loss: 1.9951 - val_accuracy: 0.2704 - 9s/epoch - 107ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8900 - accuracy: 0.3031 - val_loss: 1.9857 - val_accuracy: 0.2918 - 9s/epoch - 107ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8847 - accuracy: 0.3032 - val_loss: 1.9717 - val_accuracy: 0.2972 - 9s/epoch - 108ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8728 - accuracy: 0.3120 - val_loss: 2.0436 - val_accuracy: 0.2521 - 9s/epoch - 107ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8695 - accuracy: 0.3110 - val_loss: 2.0325 - val_accuracy: 0.2937 - 9s/epoch - 107ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8659 - accuracy: 0.3200 - val_loss: 1.9624 - val_accuracy: 0.3197 - 9s/epoch - 107ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8571 - accuracy: 0.3130 - val_loss: 2.0149 - val_accuracy: 0.3329 - 9s/epoch - 108ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8452 - accuracy: 0.3331 - val_loss: 1.9442 - val_accuracy: 0.3236 - 9s/epoch - 108ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8446 - accuracy: 0.3332 - val_loss: 2.0149 - val_accuracy: 0.2451 - 9s/epoch - 107ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8367 - accuracy: 0.3226 - val_loss: 1.9902 - val_accuracy: 0.3232 - 9s/epoch - 108ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.8284 - accuracy: 0.3321 - val_loss: 1.9550 - val_accuracy: 0.2937 - 9s/epoch - 108ms/step
# {'index': 10, 'iteration': 2, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'rmsprop', 'valid_accuracy': 0.2937062978744507, 'test_accuracy': 0.31608391608391606}
# Epoch 1/30
# 81/81 - 13s - loss: 15.7467 - accuracy: 0.1218 - val_loss: 2.3814 - val_accuracy: 0.1309 - 13s/epoch - 155ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.2449 - accuracy: 0.1563 - val_loss: 2.1963 - val_accuracy: 0.1511 - 9s/epoch - 106ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1916 - accuracy: 0.1730 - val_loss: 2.1498 - val_accuracy: 0.1838 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1249 - accuracy: 0.1868 - val_loss: 2.1125 - val_accuracy: 0.1974 - 9s/epoch - 108ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.1044 - accuracy: 0.1969 - val_loss: 2.1684 - val_accuracy: 0.1880 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0971 - accuracy: 0.2009 - val_loss: 2.0931 - val_accuracy: 0.2036 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0546 - accuracy: 0.2165 - val_loss: 2.0977 - val_accuracy: 0.2362 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.0363 - accuracy: 0.2251 - val_loss: 2.0525 - val_accuracy: 0.2280 - 9s/epoch - 107ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.0141 - accuracy: 0.2310 - val_loss: 2.0674 - val_accuracy: 0.2265 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 2.0000 - accuracy: 0.2365 - val_loss: 2.0576 - val_accuracy: 0.2424 - 9s/epoch - 107ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9855 - accuracy: 0.2356 - val_loss: 2.0441 - val_accuracy: 0.2222 - 9s/epoch - 108ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9755 - accuracy: 0.2439 - val_loss: 2.0408 - val_accuracy: 0.2358 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9658 - accuracy: 0.2464 - val_loss: 2.0269 - val_accuracy: 0.2463 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9564 - accuracy: 0.2478 - val_loss: 2.0202 - val_accuracy: 0.2413 - 9s/epoch - 107ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9383 - accuracy: 0.2683 - val_loss: 2.0300 - val_accuracy: 0.2502 - 9s/epoch - 107ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9361 - accuracy: 0.2703 - val_loss: 2.0214 - val_accuracy: 0.2754 - 9s/epoch - 113ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.9178 - accuracy: 0.2805 - val_loss: 1.9887 - val_accuracy: 0.2525 - 9s/epoch - 107ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.9101 - accuracy: 0.2843 - val_loss: 2.0044 - val_accuracy: 0.2514 - 9s/epoch - 107ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.9024 - accuracy: 0.2905 - val_loss: 2.0016 - val_accuracy: 0.2914 - 9s/epoch - 114ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8945 - accuracy: 0.2987 - val_loss: 1.9657 - val_accuracy: 0.2848 - 9s/epoch - 107ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8896 - accuracy: 0.3019 - val_loss: 1.9878 - val_accuracy: 0.2626 - 9s/epoch - 108ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8795 - accuracy: 0.3035 - val_loss: 2.0040 - val_accuracy: 0.2751 - 9s/epoch - 108ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8717 - accuracy: 0.3087 - val_loss: 1.9618 - val_accuracy: 0.3038 - 9s/epoch - 107ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8615 - accuracy: 0.3103 - val_loss: 2.0001 - val_accuracy: 0.2762 - 9s/epoch - 108ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8604 - accuracy: 0.3210 - val_loss: 1.9489 - val_accuracy: 0.3127 - 9s/epoch - 108ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8531 - accuracy: 0.3225 - val_loss: 1.9421 - val_accuracy: 0.2945 - 9s/epoch - 107ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8455 - accuracy: 0.3262 - val_loss: 1.9539 - val_accuracy: 0.3026 - 9s/epoch - 107ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8396 - accuracy: 0.3303 - val_loss: 1.9457 - val_accuracy: 0.3104 - 9s/epoch - 107ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8403 - accuracy: 0.3254 - val_loss: 1.9367 - val_accuracy: 0.3166 - 9s/epoch - 107ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.8359 - accuracy: 0.3208 - val_loss: 1.9262 - val_accuracy: 0.3182 - 9s/epoch - 107ms/step
# {'index': 11, 'iteration': 3, 'loss_name': 'categorical_crossentropy', 'optimizer_name': 'rmsprop', 'valid_accuracy': 0.3181818127632141, 'test_accuracy': 0.320979020979021}
# Epoch 1/30
# 81/81 - 13s - loss: 21.0462 - accuracy: 0.1238 - val_loss: 2.8500 - val_accuracy: 0.1282 - 13s/epoch - 158ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.3942 - accuracy: 0.1233 - val_loss: 2.2827 - val_accuracy: 0.1309 - 9s/epoch - 106ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.2803 - accuracy: 0.1216 - val_loss: 2.2757 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.2781 - accuracy: 0.1285 - val_loss: 2.2756 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.2782 - accuracy: 0.1248 - val_loss: 2.2753 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.2782 - accuracy: 0.1227 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.2781 - accuracy: 0.1223 - val_loss: 2.2748 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.2780 - accuracy: 0.1220 - val_loss: 2.2752 - val_accuracy: 0.1309 - 9s/epoch - 108ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.2780 - accuracy: 0.1210 - val_loss: 2.2750 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1253 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1242 - val_loss: 2.2752 - val_accuracy: 0.1309 - 9s/epoch - 107ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 2.2779 - accuracy: 0.1222 - val_loss: 2.2751 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 2.2778 - accuracy: 0.1210 - val_loss: 2.2749 - val_accuracy: 0.1282 - 9s/epoch - 107ms/step
# Epoch 14/30
# ...
# Epoch 29/30
# 81/81 - 9s - loss: 6.9508 - accuracy: 0.1206 - val_loss: 6.8708 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 6.8002 - accuracy: 0.1218 - val_loss: 6.7230 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# {'index': 19, 'iteration': 2, 'loss_name': 'kullback_leibler_divergence', 'optimizer_name': 'sgd', 'valid_accuracy': 0.12820513546466827, 'test_accuracy': 0.13076923076923078}
# Epoch 1/30
# 81/81 - 12s - loss: 70.8008 - accuracy: 0.1252 - val_loss: 61.7214 - val_accuracy: 0.1282 - 12s/epoch - 144ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 54.6491 - accuracy: 0.1247 - val_loss: 48.0371 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 42.8804 - accuracy: 0.1246 - val_loss: 38.0542 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 34.2844 - accuracy: 0.1246 - val_loss: 30.7509 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 27.9850 - accuracy: 0.1246 - val_loss: 25.3875 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 23.3486 - accuracy: 0.1246 - val_loss: 21.4292 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 7/30
# 81/81 - 8s - loss: 19.9173 - accuracy: 0.1246 - val_loss: 18.4894 - val_accuracy: 0.1282 - 8s/epoch - 105ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 17.3598 - accuracy: 0.1246 - val_loss: 16.2885 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 15.4364 - accuracy: 0.1246 - val_loss: 14.6241 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 13.9739 - accuracy: 0.1245 - val_loss: 13.3501 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 12.8469 - accuracy: 0.1247 - val_loss: 12.3605 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 11.9647 - accuracy: 0.1245 - val_loss: 11.5788 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 11.2616 - accuracy: 0.1245 - val_loss: 10.9494 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 10.6901 - accuracy: 0.1247 - val_loss: 10.4322 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 10.2158 - accuracy: 0.1248 - val_loss: 9.9982 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 9.8137 - accuracy: 0.1242 - val_loss: 9.6261 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 9.4657 - accuracy: 0.1241 - val_loss: 9.3008 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 9.1587 - accuracy: 0.1222 - val_loss: 9.0111 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 8.8829 - accuracy: 0.1233 - val_loss: 8.7487 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 8.6316 - accuracy: 0.1261 - val_loss: 8.5080 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 8.3995 - accuracy: 0.1217 - val_loss: 8.2844 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 8.1831 - accuracy: 0.1241 - val_loss: 8.0748 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 7.9792 - accuracy: 0.1234 - val_loss: 7.8769 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 7.7864 - accuracy: 0.1219 - val_loss: 7.6889 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 7.6028 - accuracy: 0.1233 - val_loss: 7.5095 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 7.4271 - accuracy: 0.1248 - val_loss: 7.3377 - val_accuracy: 0.1282 - 9s/epoch - 106ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 7.2587 - accuracy: 0.1223 - val_loss: 7.1727 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 7.0969 - accuracy: 0.1208 - val_loss: 7.0140 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 6.9410 - accuracy: 0.1221 - val_loss: 6.8610 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 6.7906 - accuracy: 0.1254 - val_loss: 6.7135 - val_accuracy: 0.1282 - 9s/epoch - 105ms/step
# {'index': 20, 'iteration': 3, 'loss_name': 'kullback_leibler_divergence', 'optimizer_name': 'sgd', 'valid_accuracy': 0.12820513546466827, 'test_accuracy': 0.13076923076923078}
# Epoch 1/30
# 81/81 - 12s - loss: 15.7830 - accuracy: 0.1240 - val_loss: 2.3712 - val_accuracy: 0.1344 - 12s/epoch - 150ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.2389 - accuracy: 0.1614 - val_loss: 2.1999 - val_accuracy: 0.1663 - 9s/epoch - 107ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1554 - accuracy: 0.1768 - val_loss: 2.1344 - val_accuracy: 0.1709 - 9s/epoch - 106ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1156 - accuracy: 0.1910 - val_loss: 2.1122 - val_accuracy: 0.1810 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.0816 - accuracy: 0.2054 - val_loss: 2.1463 - val_accuracy: 0.1853 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0637 - accuracy: 0.2093 - val_loss: 2.1542 - val_accuracy: 0.2009 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0391 - accuracy: 0.2211 - val_loss: 2.0821 - val_accuracy: 0.2249 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.0175 - accuracy: 0.2350 - val_loss: 2.0557 - val_accuracy: 0.2257 - 9s/epoch - 107ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.0043 - accuracy: 0.2371 - val_loss: 2.0624 - val_accuracy: 0.2397 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9937 - accuracy: 0.2381 - val_loss: 2.0479 - val_accuracy: 0.2358 - 9s/epoch - 107ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9781 - accuracy: 0.2365 - val_loss: 2.0947 - val_accuracy: 0.2389 - 9s/epoch - 107ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9645 - accuracy: 0.2513 - val_loss: 2.2453 - val_accuracy: 0.2253 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9637 - accuracy: 0.2574 - val_loss: 2.0535 - val_accuracy: 0.2393 - 9s/epoch - 106ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9393 - accuracy: 0.2681 - val_loss: 2.0436 - val_accuracy: 0.2533 - 9s/epoch - 113ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9260 - accuracy: 0.2791 - val_loss: 2.0462 - val_accuracy: 0.2568 - 9s/epoch - 106ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9153 - accuracy: 0.2885 - val_loss: 1.9914 - val_accuracy: 0.2964 - 9s/epoch - 107ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.9008 - accuracy: 0.2973 - val_loss: 2.0212 - val_accuracy: 0.2696 - 9s/epoch - 106ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.8929 - accuracy: 0.3049 - val_loss: 1.9812 - val_accuracy: 0.3050 - 9s/epoch - 107ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8845 - accuracy: 0.3030 - val_loss: 1.9961 - val_accuracy: 0.2855 - 9s/epoch - 106ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8753 - accuracy: 0.3080 - val_loss: 2.0087 - val_accuracy: 0.2665 - 9s/epoch - 107ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8653 - accuracy: 0.3176 - val_loss: 1.9887 - val_accuracy: 0.2797 - 9s/epoch - 107ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8562 - accuracy: 0.3178 - val_loss: 2.0662 - val_accuracy: 0.2630 - 9s/epoch - 107ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8504 - accuracy: 0.3174 - val_loss: 1.9738 - val_accuracy: 0.2960 - 9s/epoch - 107ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8455 - accuracy: 0.3191 - val_loss: 1.9836 - val_accuracy: 0.3182 - 9s/epoch - 107ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8381 - accuracy: 0.3188 - val_loss: 2.0207 - val_accuracy: 0.2622 - 9s/epoch - 106ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8351 - accuracy: 0.3247 - val_loss: 1.9798 - val_accuracy: 0.2832 - 9s/epoch - 107ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8286 - accuracy: 0.3265 - val_loss: 1.9493 - val_accuracy: 0.2739 - 9s/epoch - 107ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8218 - accuracy: 0.3291 - val_loss: 1.9260 - val_accuracy: 0.3143 - 9s/epoch - 107ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8192 - accuracy: 0.3236 - val_loss: 2.0543 - val_accuracy: 0.2347 - 9s/epoch - 107ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.8155 - accuracy: 0.3213 - val_loss: 1.9293 - val_accuracy: 0.3155 - 9s/epoch - 107ms/step
# {'index': 21, 'iteration': 1, 'loss_name': 'kullback_leibler_divergence', 'optimizer_name': 'rmsprop', 'valid_accuracy': 0.3154623210430145, 'test_accuracy': 0.3181818181818182}
# Epoch 1/30
# 81/81 - 12s - loss: 15.7411 - accuracy: 0.1232 - val_loss: 2.3745 - val_accuracy: 0.1406 - 12s/epoch - 150ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.2543 - accuracy: 0.1620 - val_loss: 2.1894 - val_accuracy: 0.1737 - 9s/epoch - 107ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1678 - accuracy: 0.1801 - val_loss: 2.1583 - val_accuracy: 0.1810 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1214 - accuracy: 0.1870 - val_loss: 2.1837 - val_accuracy: 0.1558 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.0920 - accuracy: 0.1972 - val_loss: 2.1999 - val_accuracy: 0.1841 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0697 - accuracy: 0.2034 - val_loss: 2.1268 - val_accuracy: 0.1593 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0466 - accuracy: 0.2178 - val_loss: 2.0850 - val_accuracy: 0.2183 - 9s/epoch - 107ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.0319 - accuracy: 0.2305 - val_loss: 2.1045 - val_accuracy: 0.2113 - 9s/epoch - 107ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.0169 - accuracy: 0.2317 - val_loss: 2.0712 - val_accuracy: 0.2350 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 2.0006 - accuracy: 0.2406 - val_loss: 2.0506 - val_accuracy: 0.2280 - 9s/epoch - 107ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9917 - accuracy: 0.2360 - val_loss: 2.0962 - val_accuracy: 0.2168 - 9s/epoch - 107ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9740 - accuracy: 0.2452 - val_loss: 2.0360 - val_accuracy: 0.2432 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9655 - accuracy: 0.2498 - val_loss: 2.0474 - val_accuracy: 0.2490 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9512 - accuracy: 0.2603 - val_loss: 2.0284 - val_accuracy: 0.2405 - 9s/epoch - 107ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9406 - accuracy: 0.2692 - val_loss: 2.0248 - val_accuracy: 0.2517 - 9s/epoch - 107ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9283 - accuracy: 0.2756 - val_loss: 1.9985 - val_accuracy: 0.2747 - 9s/epoch - 107ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.9153 - accuracy: 0.2806 - val_loss: 2.0251 - val_accuracy: 0.2758 - 9s/epoch - 107ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.9086 - accuracy: 0.2948 - val_loss: 1.9841 - val_accuracy: 0.2933 - 9s/epoch - 106ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.9017 - accuracy: 0.2999 - val_loss: 1.9844 - val_accuracy: 0.2968 - 9s/epoch - 107ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8919 - accuracy: 0.3001 - val_loss: 1.9910 - val_accuracy: 0.2774 - 9s/epoch - 107ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8838 - accuracy: 0.3090 - val_loss: 1.9659 - val_accuracy: 0.3057 - 9s/epoch - 106ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8763 - accuracy: 0.3130 - val_loss: 1.9709 - val_accuracy: 0.3023 - 9s/epoch - 107ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8701 - accuracy: 0.3160 - val_loss: 1.9722 - val_accuracy: 0.3092 - 9s/epoch - 106ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8642 - accuracy: 0.3228 - val_loss: 1.9470 - val_accuracy: 0.3061 - 9s/epoch - 106ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8572 - accuracy: 0.3265 - val_loss: 1.9769 - val_accuracy: 0.2976 - 9s/epoch - 107ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8519 - accuracy: 0.3204 - val_loss: 1.9409 - val_accuracy: 0.3023 - 9s/epoch - 106ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8417 - accuracy: 0.3297 - val_loss: 1.9496 - val_accuracy: 0.3057 - 9s/epoch - 107ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8391 - accuracy: 0.3278 - val_loss: 1.9286 - val_accuracy: 0.3178 - 9s/epoch - 106ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8322 - accuracy: 0.3334 - val_loss: 1.9399 - val_accuracy: 0.3182 - 9s/epoch - 107ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.8303 - accuracy: 0.3332 - val_loss: 2.0029 - val_accuracy: 0.2782 - 9s/epoch - 107ms/step
# {'index': 22, 'iteration': 2, 'loss_name': 'kullback_leibler_divergence', 'optimizer_name': 'rmsprop', 'valid_accuracy': 0.278166264295578, 'test_accuracy': 0.2853146853146853}
# Epoch 1/30
# 81/81 - 13s - loss: 15.7573 - accuracy: 0.1199 - val_loss: 2.6150 - val_accuracy: 0.1200 - 13s/epoch - 155ms/step
# Epoch 2/30
# 81/81 - 9s - loss: 2.2694 - accuracy: 0.1580 - val_loss: 2.2101 - val_accuracy: 0.1896 - 9s/epoch - 107ms/step
# Epoch 3/30
# 81/81 - 9s - loss: 2.1984 - accuracy: 0.1763 - val_loss: 2.1688 - val_accuracy: 0.1706 - 9s/epoch - 107ms/step
# Epoch 4/30
# 81/81 - 9s - loss: 2.1291 - accuracy: 0.1897 - val_loss: 2.1056 - val_accuracy: 0.1935 - 9s/epoch - 107ms/step
# Epoch 5/30
# 81/81 - 9s - loss: 2.1014 - accuracy: 0.2006 - val_loss: 2.0989 - val_accuracy: 0.1950 - 9s/epoch - 107ms/step
# Epoch 6/30
# 81/81 - 9s - loss: 2.0666 - accuracy: 0.1992 - val_loss: 2.0681 - val_accuracy: 0.2207 - 9s/epoch - 107ms/step
# Epoch 7/30
# 81/81 - 9s - loss: 2.0481 - accuracy: 0.2115 - val_loss: 2.0517 - val_accuracy: 0.2288 - 9s/epoch - 106ms/step
# Epoch 8/30
# 81/81 - 9s - loss: 2.0241 - accuracy: 0.2273 - val_loss: 2.0458 - val_accuracy: 0.2246 - 9s/epoch - 106ms/step
# Epoch 9/30
# 81/81 - 9s - loss: 2.0051 - accuracy: 0.2389 - val_loss: 2.0326 - val_accuracy: 0.2428 - 9s/epoch - 107ms/step
# Epoch 10/30
# 81/81 - 9s - loss: 1.9959 - accuracy: 0.2453 - val_loss: 2.0099 - val_accuracy: 0.2494 - 9s/epoch - 107ms/step
# Epoch 11/30
# 81/81 - 9s - loss: 1.9776 - accuracy: 0.2508 - val_loss: 2.0113 - val_accuracy: 0.2603 - 9s/epoch - 108ms/step
# Epoch 12/30
# 81/81 - 9s - loss: 1.9597 - accuracy: 0.2583 - val_loss: 1.9880 - val_accuracy: 0.2634 - 9s/epoch - 107ms/step
# Epoch 13/30
# 81/81 - 9s - loss: 1.9403 - accuracy: 0.2603 - val_loss: 2.0312 - val_accuracy: 0.2560 - 9s/epoch - 107ms/step
# Epoch 14/30
# 81/81 - 9s - loss: 1.9308 - accuracy: 0.2622 - val_loss: 1.9866 - val_accuracy: 0.2650 - 9s/epoch - 107ms/step
# Epoch 15/30
# 81/81 - 9s - loss: 1.9180 - accuracy: 0.2603 - val_loss: 1.9629 - val_accuracy: 0.2657 - 9s/epoch - 107ms/step
# Epoch 16/30
# 81/81 - 9s - loss: 1.9029 - accuracy: 0.2682 - val_loss: 1.9451 - val_accuracy: 0.2638 - 9s/epoch - 107ms/step
# Epoch 17/30
# 81/81 - 9s - loss: 1.8923 - accuracy: 0.2647 - val_loss: 1.9600 - val_accuracy: 0.2494 - 9s/epoch - 107ms/step
# Epoch 18/30
# 81/81 - 9s - loss: 1.8824 - accuracy: 0.2691 - val_loss: 1.9455 - val_accuracy: 0.2642 - 9s/epoch - 107ms/step
# Epoch 19/30
# 81/81 - 9s - loss: 1.8713 - accuracy: 0.2664 - val_loss: 1.9656 - val_accuracy: 0.2603 - 9s/epoch - 107ms/step
# Epoch 20/30
# 81/81 - 9s - loss: 1.8646 - accuracy: 0.2693 - val_loss: 1.9317 - val_accuracy: 0.2603 - 9s/epoch - 107ms/step
# Epoch 21/30
# 81/81 - 9s - loss: 1.8619 - accuracy: 0.2643 - val_loss: 1.9048 - val_accuracy: 0.2634 - 9s/epoch - 106ms/step
# Epoch 22/30
# 81/81 - 9s - loss: 1.8469 - accuracy: 0.2717 - val_loss: 1.9379 - val_accuracy: 0.2572 - 9s/epoch - 107ms/step
# Epoch 23/30
# 81/81 - 9s - loss: 1.8419 - accuracy: 0.2693 - val_loss: 1.9340 - val_accuracy: 0.2541 - 9s/epoch - 107ms/step
# Epoch 24/30
# 81/81 - 9s - loss: 1.8345 - accuracy: 0.2719 - val_loss: 1.9182 - val_accuracy: 0.2595 - 9s/epoch - 107ms/step
# Epoch 25/30
# 81/81 - 9s - loss: 1.8301 - accuracy: 0.2725 - val_loss: 1.9850 - val_accuracy: 0.2560 - 9s/epoch - 107ms/step
# Epoch 26/30
# 81/81 - 9s - loss: 1.8248 - accuracy: 0.2692 - val_loss: 1.9118 - val_accuracy: 0.2591 - 9s/epoch - 106ms/step
# Epoch 27/30
# 81/81 - 9s - loss: 1.8178 - accuracy: 0.2764 - val_loss: 1.9360 - val_accuracy: 0.2576 - 9s/epoch - 107ms/step
# Epoch 28/30
# 81/81 - 9s - loss: 1.8142 - accuracy: 0.2772 - val_loss: 2.0197 - val_accuracy: 0.2914 - 9s/epoch - 107ms/step
# Epoch 29/30
# 81/81 - 9s - loss: 1.8081 - accuracy: 0.2811 - val_loss: 1.8846 - val_accuracy: 0.2685 - 9s/epoch - 107ms/step
# Epoch 30/30
# 81/81 - 9s - loss: 1.8124 - accuracy: 0.2920 - val_loss: 1.8822 - val_accuracy: 0.2681 - 9s/epoch - 106ms/step
# {'index': 23, 'iteration': 3, 'loss_name': 'kullback_leibler_divergence', 'optimizer_name': 'rmsprop', 'valid_accuracy': 0.26806527376174927, 'test_accuracy': 0.272027972027972}
# CPU times: user 1h 12min 6s, sys: 2min 29s, total: 1h 14min 36s
# Wall time: 1h 57min 45s

# %%
df_result
# Out:
#    index iteration                    loss_name optimizer_name  \
# 0      0         1     categorical_crossentropy           adam
# 1      1         2     categorical_crossentropy           adam
# 2      2         3     categorical_crossentropy           adam
# 3      3         1     categorical_crossentropy          nadam
# 4      4         2     categorical_crossentropy          nadam
# 5      5         3     categorical_crossentropy          nadam
# 6      6         1     categorical_crossentropy            sgd
# 7      7         2     categorical_crossentropy            sgd
# 8      8         3     categorical_crossentropy            sgd
# 9      9         1     categorical_crossentropy        rmsprop
# 10    10         2     categorical_crossentropy        rmsprop
# 11    11         3     categorical_crossentropy        rmsprop
# 12    12         1  kullback_leibler_divergence           adam
# 13    13         2  kullback_leibler_divergence           adam
# 14    14         3  kullback_leibler_divergence           adam
# 15    15         1  kullback_leibler_divergence          nadam
# 16    16         2  kullback_leibler_divergence          nadam
# 17    17         3  kullback_leibler_divergence          nadam
# 18    18         1  kullback_leibler_divergence            sgd
# 19    19         2  kullback_leibler_divergence            sgd
# 20    20         3  kullback_leibler_divergence            sgd
# 21    21         1  kullback_leibler_divergence        rmsprop
# 22    22         2  kullback_leibler_divergence        rmsprop
# 23    23         3  kullback_leibler_divergence        rmsprop
#
#     valid_accuracy  test_accuracy
# 0         0.130925       0.125874
# 1         0.130925       0.125874
# 2         0.128205       0.130769
# 3         0.309246       0.300699
# 4         0.321678       0.309091
# 5         0.278166       0.284615
# 6         0.130925       0.125874
# 7         0.130925       0.125874
# 8         0.130925       0.125874
# 9         0.327117       0.311888
# 10        0.293706       0.316084
# 11        0.318182       0.320979
# 12        0.130925       0.125874
# 13        0.130925       0.125874
# 14        0.128205       0.130769
# 15        0.316239       0.318182
# 16        0.322067       0.318182
# 17        0.130925       0.125874
# 18        0.130925       0.125874
# 19        0.128205       0.130769
# 20        0.128205       0.130769
# 21        0.315462       0.318182
# 22        0.278166       0.285315
# 23        0.268065       0.272028

# %% [markdown]
# Выводы:
# 1. Наилучший результат по значению accuracy на тесте показала комбинация функции потерь "categorical_crossentropy" и оптимизатора "rmsprop"
# 2. Наиболее высокие результаты показывают модели, в которых в качестве оптимизатора взяты "rmsprop" или "nadam"
# 3. Выбор функции потерь между "categorical_crossentropy" и "kullback_leibler_divergence" не оказывает сильного влияния на результат для данной задачи, т.к. результаты для обеих функций потерь схожи
